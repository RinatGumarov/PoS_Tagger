# %%
import string
def contains_letter(w):
    for l in w:
        if l in l.lower() in 'abcdefghijklmnopqrstuvwxyz':
            return True
    return False
#sentence: [w1, w2, ...], index: the index of the word
def features(sentence, index):
    features = {}
    word = sentence[index]
    prevw = '' if index == 0 else sentence[index - 1]
    nextw = '' if index == len(sentence) - 1 else sentence[index + 1]
    return {
        'word': word,
        'is_first': index == 0,
        'is_last': index == len(sentence) - 1,
        'is_capitalized': word[0].upper() == word[0],
#         'is_all_caps': word.upper() == word,
#         'is_all_lower': word.lower() == word,
        'prefix-1': word[0],
        'prefix-2': word[:2],# some specific signs
        'suffix-1': word[-1],# y
        'suffix-2': word[-2:],#ed, ly
        'suffix-3': word[-3:],#ing
        'suffix-4': word[-4:],
        'digit_start': word[0] in '0123456789',
        'vowel_last': word[-1] in 'aeiouy',
        'vowels': ''.join([i for i in word if i in 'aeiou']),
        'is_punctuation': word in string.punctuation,
#         'prev_word': prevw,
#         'next_word': nextw,
#         'prev-suffix-2': prevw[-2:],
        'prev-suffix-3': prevw[-3:],
#         'next-suffix-2': nextw[-2:],
        'next-suffix-3': nextw[-3:],        
        'contains_letter': contains_letter(word),
        'is_numeric': word.isdigit(),
        'capitals_inside': sentence[index][1:].lower() != sentence[index][1:]
    }
 
import pprint 
pprint.pprint(features(['This', 'is', 'a', 'sentence', '234,53'], 3))
# Out:
# {'capitals_inside': False,
#  'contains_letter': True,
#  'digit_start': False,
#  'is_capitalized': False,
#  'is_first': False,
#  'is_last': False,
#  'is_numeric': False,
#  'is_punctuation': False,
#  'next-suffix-3': ',53',
#  'prefix-1': 's',
#  'prefix-2': 'se',
#  'prev-suffix-3': 'a',
#  'suffix-1': 'e',
#  'suffix-2': 'ce',
#  'suffix-3': 'nce',
#  'suffix-4': 'ence',
#  'vowel_last': True,
#  'vowels': 'eee',
#  'word': 'sentence'}

# %%
def remove_tags(tagged_sentence):
    return [w for t, w in tagged_sentence]

# %%
def transform_to_sentences(filename):
    raw = open(filename)
    tagget_sentences = []
    sentence = []
    for line in raw:
        if(line == '\n' or line == ''):
            tagget_sentences.append(sentence)
            sentence = []
            continue
        sentence.append(line.strip().split('\t'))
    return tagget_sentences

# %%
tags = []
raw = open('pos_train.conll')
sentence = []
for line in raw:
    if(line == '\n' or line.strip() == ''):
        continue
    x, y = line.strip().split('\t')
    if x not in tags:
        tags.append(x)
        print(line)
print(tags)
# Out:
# NNP	Antick
#
# NN	post
#
# :	:
#
# CD	2010
#
# (	(
#
# )	)
#
# IN	by
#
# URL	http://bit.ly/as8fvc
#
# RT	RT
#
# USR	@DIVINEDYNASTY
#
# HT	#THEREDROOM
#
# .	.
#
# WRB	when
#
# PRP	i
#
# VBP	compliment
#
# MD	wo
#
# RB	n't
#
# VB	believe
#
# UH	&lt;
#
# VBG	doin
#
# JJ	good
#
# ,	,
#
# CC	&
#
# PRP$	my
#
# DT	a
#
# JJS	Most
#
# NNS	things
#
# VBZ	seems
#
# RBR	more
#
# VBN	Thrilled
#
# VBD	increased
#
# TO	to
#
# RP	out
#
# EX	there
#
# POS	's
#
# WP	what
#
# WDT	that
#
# FW	Etc
#
# JJR	darker
#
# ''	"
#
# NNPS	kids
#
# SYM	&lt;
#
# RBS	most
#
# VPP	please
#
# O	"..
#
# LS	1
#
# TD	a
#
# ['NNP', 'NN', ':', 'CD', '(', ')', 'IN', 'URL', 'RT', 'USR', 'HT', '.', 'WRB', 'PRP', 'VBP', 'MD', 'RB', 'VB', 'UH', 'VBG', 'JJ', ',', 'CC', 'PRP$', 'DT', 'JJS', 'NNS', 'VBZ', 'RBR', 'VBN', 'VBD', 'TO', 'RP', 'EX', 'POS', 'WP', 'WDT', 'FW', 'JJR', "''", 'NNPS', 'SYM', 'RBS', 'VPP', 'O', 'LS', 'TD']

# %%
test_sentences = transform_to_sentences('pos_test.conll')
train_sentences = transform_to_sentences('pos_train.conll')
print(test_sentences[0])
print(train_sentences[0])
# Out:
# [['CD', '2'], ['NNS', 'days'], ['IN', 'til'], ['HT', '#houseofmirrors'], ['HT', '#houseofmirrors'], ['HT', '#houseofmirrors'], ['HT', '#houseofmirrors'], ['HT', '#houseofmirrors'], ['HT', '#houseofmirrors'], ['HT', '#houseofmirrors'], ['HT', '#houseofmirrors'], ['.', '!']]
# [['NNP', 'Antick'], ['NNP', 'Musings'], ['NN', 'post'], [':', ':'], ['NNP', 'Book-A-Day'], ['CD', '2010'], ['NN', '#'], ['CD', '243'], ['(', '('], ['CD', '10/4'], [')', ')'], [':', '--'], ['NNP', 'Gray'], ['NNP', 'Horses'], ['IN', 'by'], ['NNP', 'Hope'], ['NNP', 'Larson'], ['URL', 'http://bit.ly/as8fvc']]

# %%
def transform_to_dataset(tagged_sentences):
    X, y = [], []
 
    for tagged in tagged_sentences:
        for index in range(len(tagged)):
            X.append(features(remove_tags(tagged), index))
            y.append(tagged[index][0])
 
    return X, y

X, y = transform_to_dataset(train_sentences)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import Pipeline
 
clf = Pipeline([
    ('vectorizer', DictVectorizer(sparse=False)),
    ('classifier', DecisionTreeClassifier(criterion='entropy'))
])
 
clf.fit(X, y)
 
X_test, y_test = transform_to_dataset(test_sentences)

print("Accuracy:", clf.score(X_test, y_test))


# Accuracy: 0.814005352364 without prev and next
# Out:
# Accuracy: 0.814005352364

# %%
print(clf)
# Out:
# Pipeline(memory=None,
#      steps=[('vectorizer', DictVectorizer(dtype=<class 'numpy.float64'>, separator='=', sort=True,
#         sparse=False)), ('classifier', DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'))])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, clf.predict(X_test)))
# Out:
#              precision    recall  f1-score   support
#
#          ''       1.00      1.00      1.00        10
#           (       0.67      1.00      0.80         4
#           )       1.00      1.00      1.00         6
#           ,       1.00      1.00      1.00        44
#           .       0.97      0.99      0.98       125
#           :       0.94      0.94      0.94        81
#          CC       0.90      0.98      0.93        44
#          CD       0.74      0.94      0.83        36
#          DT       0.92      0.95      0.94       115
#          EX       1.00      0.25      0.40         4
#          HT       1.00      1.00      1.00        26
#          IN       0.93      0.90      0.91       168
#          JJ       0.73      0.50      0.60       119
#         JJR       0.75      0.75      0.75         4
#         JJS       1.00      0.33      0.50         3
#          MD       1.00      0.96      0.98        27
#          NN       0.70      0.74      0.72       287
#         NNP       0.59      0.69      0.63       173
#         NNS       0.73      0.74      0.74        66
#        NONE       0.00      0.00      0.00         2
#         PDT       0.00      0.00      0.00         1
#         POS       0.57      1.00      0.73         4
#         PRP       0.96      0.97      0.96       165
#        PRP$       1.00      0.84      0.92        32
#          RB       0.75      0.84      0.79        92
#         RBR       0.80      0.67      0.73         6
#          RP       0.92      0.79      0.85        14
#          RT       1.00      1.00      1.00        24
#         SYM       1.00      0.33      0.50         3
#          TO       1.00      0.95      0.98        42
#          UH       0.69      0.63      0.66        63
#         URL       0.87      0.83      0.85        24
#         USR       1.00      0.98      0.99        64
#          VB       0.66      0.63      0.64        93
#         VBD       0.67      0.68      0.67        44
#         VBG       0.79      0.89      0.84        35
#         VBN       0.37      0.39      0.38        18
#         VBP       0.72      0.68      0.70        82
#         VBZ       0.85      0.71      0.77        58
#         WDT       0.00      0.00      0.00         1
#          WP       1.00      0.90      0.95        10
#         WRB       1.00      1.00      1.00        23
#
# avg / total       0.82      0.81      0.81      2242
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_pred = clf.predict(X_test)

# %%
for m, n, k in zip([x['word'] for x in X_test], y_pred, y_test):
    if (n != k):
        print(m,'f:'+ n,'t:'+ k)
# Out:
# case f:IN t:NN
# JV f:NNP t:NN
# leads f:NNS t:VBZ
# 4-1 f:CD t:JJ
# scores f:NNS t:VBZ
# New f:NNP t:JJ
# TheDeAndreWay f:URL t:NNP
# The f:NNP t:DT
# souljaboytellem-iga.ning.com f:NN t:URL
# born f:NN t:VBN
# RETWEET f:NNP t:VB
# Funniest f:NN t:JJS
# heard f:NN t:VBD
# Wingo f:UH t:NNP
# wood f:NN t:NNP
# scared f:VBD t:VBN
# came f:NN t:VBD
# pandora f:NN t:NNP
# tho f:IN t:RB
# so f:CC t:IN
# yo f:UH t:PRP$
# tweet f:VB t:NN
# *kisses f:NNP t:VBZ
# ass**sneezes f:VBZ t:NN
# after* f:NN t:RB
# then f:RB t:IN
# hp6 f:NN t:NNP
# So f:RB t:UH
# chi f:VBG t:NNP
# whts f:NNP t:WP
# Fuck f:JJ t:UH
# FRIDAY f:VB t:NNP
# wet f:VB t:JJ
# cold f:VBD t:JJ
# High f:NNP t:JJ
# low f:IN t:JJ
# Goin f:NNP t:VBG
# BEST f:NNP t:JJS
# friends f:NNS t:NN
# party f:NNP t:NN
# As f:UH t:IN
# see f:VBP t:VB
# taylor f:NN t:NNP
# ~HAPPY f:NNP t:JJ
# TAYLOR f:NN t:NNP
# LUVZ f:NNP t:VBP
# Hey f:DT t:UH
# both f:NN t:DT
# drafted f:VBD t:VBN
# stared f:VBN t:VBD
# live f:VB t:VBP
# awaiting f:JJ t:VBG
# become f:IN t:VBP
# Amber f:VBD t:NNP
# Le f:PRP t:NNP
# LFW f:NN t:NNP
# Be f:VB t:VBP
# 15th f:CD t:JJ
# get f:VB t:VBP
# hands f:VBZ t:NNS
# dry f:VB t:JJ
# shampoo f:UH t:NN
# it'd f:NN t:PRP
# happen f:VBN t:VB
# inna f:NNP t:IN
# 3times f:RB t:NNS
# tender f:JJR t:JJ
# pleased f:VBD t:JJ
# So f:RB t:UH
# start f:NN t:VBP
# Stop f:JJ t:VBP
# COLLEGE f:NN t:NNP
# TAILGATE f:NN t:NNP
# Yellow f:UH t:NNP
# Lot f:VBD t:NNP
# $7 f:NNP t:NNS
# dead f:NN t:JJ
# Maybe f:NNP t:RB
# Weeeeee f:NNP t:UH
# facee f:NNS t:NN
# wild f:NN t:JJ
# Internet f:NNP t:NN
# sucks f:NNS t:VBZ
# Minimalist f:NN t:JJ
# Web f:NNP t:NN
# Design f:NNP t:NN
# Less f:NNP t:JJR
# EVERYTHING f:VBG t:NN
# STAND f:CC t:VBP
# TURNS f:NNP t:VBZ
# ON f:UH t:RP
# HAPPENS f:NNP t:VBZ
# BECOME f:VB t:VBP
# MAIN f:NNP t:JJ
# SOURCE f:VB t:NN
# PAIN f:NNP t:NN
# black f:RB t:NN
# friday f:NNP t:NN
# work f:NN t:VBP
# 2-11 f:CD t:JJ
# shopping f:VBG t:NN
# spree f:NNS t:NN
# People f:NN t:NNS
# tweet f:VB t:VBP
# follow f:NN t:VB
# yayi f:VBG t:PRP
# aka f:NNP t:VBN
# derek f:NN t:NNP
# [ f:: t:NONE
# ] f:: t:NONE
# New f:NNP t:JJ
# Bed f:NNP t:NN
# Game f:NN t:JJ
# Someone f:NNP t:NN
# Her f:NNP t:PRP$
# husband f:VB t:NN
# love f:VBP t:VB
# stickers f:NNP t:NNS
# Ever f:NNP t:RB
# wonder f:NN t:VBP
# there f:RB t:EX
# Touch f:NN t:VB
# find f:VBP t:VB
# as f:IN t:RB
# obsessed f:VBN t:VBD
# obsessed f:VBN t:VBD
# sexiness f:NN t:NNS
# find f:VBP t:VB
# - f:UH t::
# Elliot f:NN t:NNP
# yous f:JJ t:PRP
# government f:JJ t:NN
# finance f:NN t:VBP
# unfollowing f:VBG t:NN
# spree f:NNS t:NN
# have f:VB t:VBP
# .. f:. t::
# Such f:NNP t:JJ
# shiny f:NN t:JJ
# Love f:NNP t:VBP
# Anyways f:NNS t:UH
# busy f:VB t:JJ
# Aggressive f:RB t:JJ
# Kids f:NNP t:NNS
# ADHD f:NN t:NNP
# May f:NNP t:MD
# Need f:VBP t:VB
# Antipsychotic f:NNP t:JJ
# Meds f:NNP t:NNS
# pope f:JJ t:NNP
# birmingham f:NN t:NNP
# ok f:UH t:JJ
# tryy~ f:NN t:VB
# Sharks f:NNS t:NNP
# Pretty f:DT t:RB
# lost f:NN t:VBD
# filled f:VBD t:VBN
# unfortunately f:RB t:JJ
# theycame f:DT t:VB
# uk f:NN t:USR
# seen f:VBN t:VBZ
# Event f:NN t:NNP
# www.africaunsigned.com/asn f:NN t:URL
# custom f:URL t:JJ
# simone f:NN t:NNP
# then f:RB t:IN
# 2morrow f:NNP t:NN
# 2 f:CD t:TO
# festival f:VBP t:NN
# 4 f:CD t:IN
# 2night f:NNP t:NN
# an f:DT t:CC
# .!!!!!!! f:: t:.
# Top f:NNP t:JJ
# amateurs f:VBZ t:NNS
# North f:RB t:NNP
# failing f:JJ t:VBG
# East f:NN t:NNP
# Chal f:NN t:NNP
# there f:RB t:EX
# cockatoo f:RB t:NN
# sill f:RB t:NN
# showered f:VBN t:VBD
# ( f:( t:UH
# 5x f:CD t:NN
# 's f:POS t:VBZ
# answer f:DT t:VB
# that f:DT t:IN
# MAYBE f:NNP t:RB
# ohhh f:IN t:UH
# atmosphere f:RB t:NNP
# theirs f:NNS t:PRP
# call f:VBP t:NN
# Yahoo f:UH t:NNP
# pregnant f:NN t:JJ
# Jacquelin f:RB t:NNP
# watched f:VBN t:VBD
# Public f:NNP t:NN
# Health f:NNP t:NN
# [ f:( t::
# Pump f:NNP t:NN
# Handle] f:NNP t:NN
# Earlier f:NNP t:RBR
# Commissioner f:NNP t:NN
# present f:JJ t:VBP
# trillion f:NN t:CD
# BETTER f:NNP t:RBR
# 5th f:CD t:JJ
# BABY( f:NN t:UH
# : f:: t:UH
# gave f:VBP t:VBD
# 4 f:CD t:IN
# bill f:VB t:NN
# put f:VBP t:VBD
# n f:CC t:IN
# her f:PRP t:PRP$
# eat f:VBD t:VB
# "... f:IN t::
# -______- f:NNP t:UH
# HELLA f:NNP t:UH
# So f:RB t:UH
# about f:IN t:JJ
# within f:NN t:IN
# Boise f:VB t:NNP
# orange f:VB t:JJ
# orange f:VB t:JJ
# jerseys f:VBZ t:NNS
# blue f:VB t:JJ
# helmets f:RB t:NNS
# Orange f:NNP t:JJ
# jerseys f:VBZ t:NNS
# match f:NN t:VBP
# regular f:NN t:JJ
# blu f:PRP t:JJ
# site f:JJ t:NN
# order f:VB t:NN
# required f:NN t:VBN
# BONG f:NN t:NNP
# WENT f:UH t:VBD
# 5-O f:NNP t:JJ
# LAST f:NNP t:JJ
# NIGHT f:NNP t:NN
# included f:VBD t:VBN
# matters f:NNS t:VBZ
# Cruise f:VB t:NNP
# Gate f:NN t:NNP
# First f:NN t:JJ
# Coated f:JJ t:NNP
# P-D f:NN t:NNP
# http://bit.ly/gsSina f:NNP t:URL
# Ooof f:NN t:UH
# Help f:NNP t:VB
# lbs f:NNP t:NNS
# chitlins f:NNS t:NN
# !" f:. t::
# *Barf* f:NNP t:UH
# looking f:VBG t:JJ
# lake f:JJ t:NN
# ordered f:VBN t:VBD
# enters f:NNS t:VBZ
# pm f:NN t:JJ
# Shore f:IN t:NNP
# overrated f:VBD t:VBN
# history f:JJ t:NN
# fat f:NN t:JJ
# sleep f:VB t:NN
# Bonfire f:NNP t:NN
# are f:VBP t:VBZ
# welcome f:JJ t:VB
# joe f:NN t:NNP
# Deez f:NNP t:DT
# niggaz f:NN t:NNS
# deez f:VBN t:DT
# niggaz f:NN t:NNS
# shit f:NN t:JJ
# out f:RP t:IN
# eachother f:RBR t:NN
# plez f:NN t:VB
# https://owensoto.wordpress.com/ f:URL t:NN
# youtube f:NN t:NNP
# have f:VB t:VBP
# back f:RB t:JJ
# spoke f:NN t:VBD
# bless f:JJ t:VBZ
# Thanks f:NNS t:UH
# Lucilles f:NNS t:NNP
# Famous f:JJ t:NNP
# have f:VBP t:VB
# evry f:RB t:JJ
# compete f:NN t:VB
# sum f:NN t:DT
# hawt f:NN t:JJ
# 2 f:CD t:TO
# my$ f:NN t:PRP$
# leave f:VBP t:VB
# ride f:VBP t:NN
# Deal f:NN t:VB
# Your f:NNP t:PRP$
# Crush f:NNP t:NN
# Taken f:NNP t:VBN
# 's f:POS t:VBZ
# run f:NN t:VB
# = f:UH t:SYM
# Pretty f:NNP t:RB
# detective f:VB t:NN
# go f:VB t:VBP
# commercial f:JJ t:NN
# blows f:NNS t:VBZ
# . f:. t:UH
# _ f:: t:UH
# . f:. t:UH
# DJ f:NN t:NNP
# set f:VBP t:NN
# The f:DT t:NNP
# Standard f:NN t:NNP
# say f:VBP t:VB
# text f:VBP t:NN
# as f:RB t:IN
# LOL f:UH t:NN
# WAYNE f:UH t:NNP
# SOLD f:NN t:VBN
# OUT.....'nuff f:NNP t:RP
# There f:UH t:EX
# such f:NN t:JJ
# that f:RB t:DT
# goal f:JJ t:NN
# fixing f:JJ t:VBG
# that f:DT t:WDT
# one-time f:NN t:JJ
# courtesy f:JJ t:NN
# love f:VBP t:VB
# IDWT f:PRP t:NNP
# live f:VB t:JJ
# ces f:PRP t:NNP
# fan-girl f:NN t:VB
# tend f:NN t:VBP
# fantasy f:JJ t:NN
# and f:CC t:JJ
# There f:UH t:RB
# belles f:VBZ t:NNP
# 4 f:CD t:IN
# *N*I*K*K*I* f:UH t:NNP
# ik f:IN t:UH
# 2 f:CD t:RB
# At f:NNP t:IN
# wide f:NN t:RB
# drags f:NNS t:VBZ
# Half f:JJ t:PDT
# baked f:VBD t:JJ
# high f:NN t:JJ
# grandma f:NNP t:NN
# puff f:NN t:VB
# puff f:NN t:VB
# pass f:NN t:VB
# &lt; f:CC t:SYM
# GREEN f:VBG t:NNP
# mcdonalds f:NNS t:NN
# t.i f:VBG t:NN
# rose f:NN t:NNP
# 's f:POS t:VBZ
# rose f:NN t:NNP
# Gosh f:NNP t:UH
# handle f:NN t:VBP
# 2011 f:UH t:CD
# Time f:NNP t:NN
# Buyer f:NNP t:NN
# Incentives f:NNP t:NNS
# Incen f:NNP t:NN
# jeez f:VBN t:UH
# hear f:VB t:VBP
# Colt f:VBD t:NNP
# died f:VBN t:VBD
# As f:UH t:IN
# nyt f:RB t:NN
# so f:RB t:IN
# imma f:IN t:PRP
# nyt f:RB t:NN
# bles f:PRP t:VBZ
# swear f:NN t:VBP
# suprising f:NN t:JJ
# once f:NN t:RB
# no f:DT t:UH
# ask f:VB t:VBP
# fucking f:JJ t:RB
# have f:VBP t:VB
# dank f:NN t:URL
# je f:PRP t:IN
# Jopulse f:VB t:NNP
# Get f:VBP t:VB
# Little f:NNP t:JJ
# Secret f:NNP t:NN
# Avail f:NNP t:VB
# Mortgage f:NNP t:NN
# found f:NN t:VBN
# preserve f:VBP t:VB
# eat f:VBD t:VBP
# 2 f:CD t:RB
# grilled f:VBD t:JJ
# fried f:VBN t:JJ
# Time f:NNP t:NN
# Stop f:NNP t:VB
# In f:IN t:RP
# Then f:NNP t:RB
# Quick f:NNP t:JJ
# Service f:NN t:JJ
# Drive f:RB t:NN
# Thru f:NNP t:NN
# Window f:NNP t:NN
# look f:VB t:NN
# pet f:VB t:NN
# peeve f:VBP t:NN
# albums f:VBZ t:NNS
# lowercase f:VBP t:JJ
# track f:VB t:NN
# eat f:VBD t:VB
# aint f:NN t:VBP
# ate f:NN t:VB
